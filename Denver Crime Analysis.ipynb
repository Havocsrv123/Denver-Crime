# %% [markdown]
# # Exploring Denver crime data

# %%
import pandas as pd
import numpy as np

# %%
#read csv for teh crimes

df = pd.read_csv('crime2021.csv')
df.head()
# Out:
#    incident_id         offense_id  offense_code  offense_code_extension  \
# 0   2021387586   2021387586299900          2999                       0
# 1   2021415767   2021415767299900          2999                       0
# 2  20216014714  20216014714299900          2999                       0
# 3   2021321536   2021321536299900          2999                       0
# 4   2021387948   2021387948299900          2999                       0
#
#            offense_type_id offense_category_id first_occurrence_date  \
# 0  criminal-mischief-other     public-disorder   7/7/2021 9:02:00 PM
# 1  criminal-mischief-other     public-disorder  7/21/2021 4:41:00 PM
# 2  criminal-mischief-other     public-disorder  7/13/2021 6:30:00 AM
# 3  criminal-mischief-other     public-disorder  6/6/2021 11:45:00 PM
# 4  criminal-mischief-other     public-disorder  7/8/2021 12:00:00 AM
#
#    last_occurrence_date         reported_date       incident_address  \
# ...

# %%
df.shape
# Out:
# (72954, 20)

# %%
print(df['reported_date'].max(),df['reported_date'].min())
# Out:
# 9/9/2022 3:00:00 PM 1/1/2021 10:01:00 PM

# %%
#read offense codes
cd = pd.read_csv('offense_codes.csv')
cd.head()
# Out:
#    OBJECTID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0         1          2804                       1
# 1         2          2804                       2
# 2         3          2901                       0
# 3         4          2902                       0
# 4         5          2903                       0
#
#                   OFFENSE_TYPE_ID                      OFFENSE_TYPE_NAME  \
# 0      stolen-property-possession          Possession of stolen property
# 1  fraud-possess-financial-device       Possession of a financial device
# 2                damaged-prop-bus              Damaged business property
# 3       criminal-mischief-private  Criminal mischief to private property
# 4        criminal-mischief-public   Criminal mischief to public property
#
#   OFFENSE_CATEGORY_ID OFFENSE_CATEGORY_NAME  IS_CRIME  IS_TRAFFIC
# 0    all-other-crimes      All Other Crimes         1           0
# 1    all-other-crimes      All Other Crimes         1           0
# ...

# %%
df['offense_code'].value_counts()
# Out:
# 2404    12399
# 2999     9094
# 2305     7782
# 2399     6261
# 2304     5817
#         ...
# 3501        1
# 5011        1
# 907         1
# 5302        1
# 3582        1
# Name: offense_code, Length: 128, dtype: int64

# %%
cd[cd['OFFENSE_CODE'] == 2404]
# Out:
#      OBJECTID  OFFENSE_CODE  OFFENSE_CODE_EXTENSION         OFFENSE_TYPE_ID  \
# 261       262          2404                       0  theft-of-motor-vehicle
#
#        OFFENSE_TYPE_NAME OFFENSE_CATEGORY_ID OFFENSE_CATEGORY_NAME  IS_CRIME  \
# 261  Motor vehicle theft          auto-theft            Auto Theft         1
#
#      IS_TRAFFIC
# 261           0
